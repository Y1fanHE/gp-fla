# %%
from plot_tools import get_networkx_plot_var, set_ax
import matplotlib.pyplot as plt

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/parity4-5.zip", 9, 16, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/parity4-5-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/parity4-7.zip", 9, 16, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/parity4-7-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/parity6-5.zip", 48, 64, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/parity6-5-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/parity6-7.zip", 48, 64, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/parity6-7-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/ant1-5.zip", 75, 89, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/ant1-5-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/ant1-7.zip", 75, 89, monotonic=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/ant1-7-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/nguyen2-5.zip", 1, 1e-5, direction=-1, monotonic=True, log_scale=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/nguyen2-5-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/nguyen2-7.zip", 1, 1e-5, direction=-1, monotonic=True, log_scale=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/nguyen2-7-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/nguyen9-5.zip", 10, 1e-5, direction=-1, monotonic=True, log_scale=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/nguyen9-5-3d.svg", bbox_inches="tight")

# %%
vertex_xyz, edge_xyz, vertex_size, edge_width, vertex_color, edge_color = get_networkx_plot_var("dat/nguyen9-7.zip", 10, 1e-5, direction=-1, monotonic=True, log_scale=True)
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection="3d")
for i, vizedge in enumerate(edge_xyz):
    ax.plot(*vizedge.T, color=edge_color[i], lw=edge_width[i])
ax.scatter(*vertex_xyz.T, s=vertex_size, ec="black", fc=vertex_color, alpha=1.)
set_ax(ax)
plt.savefig("lons/nguyen9-7-3d.svg", bbox_inches="tight")
